# %% [markdown]
# ### 부산광역시 인구동태 현황으로 스타벅스 지점과의 연관성 찾기

# %%
# !pip install matplotlib
# !pip install pandas

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import matplotlib.dates as mdates
import pandas as pd
import numpy as np

# %%
# !pwd # !dir/w

# %%
file_path = './부산광역시 주민등록인구통계_20231231.csv'
# CSV 파일읽기
ingu_data = pd.read_csv(file_path, encoding='EUC-KR')
ingu_data= ingu_data[['구군','인구수(명)']]
ingu_data= ingu_data.sort_values(by='인구수(명)', ascending=False)
ingu_data.head()
# Out:
#      구군  인구수(명)
# 8  해운대구  385618
# 4  부산진구  362505
# 9   사하구  302947
# 7    북구  275773
# 5   동래구  272178

# %%
star_path = './starbucks_20250411113937.csv'
star_data = pd.read_csv(star_path, encoding='UTF-8')
star_data.columns = ['no.','name','lat','lon','addr','type']
star_data
# Out:
#      no.      name        lat         lon  \
# 0      0   금정남산동DT  35.262179  129.091325
# 1      1    금정구청DT  35.238814  129.092986
# 2      2    온천장역DT  35.224006  129.086560
# 3      3     부산대정문  35.232122  129.084496
# 4      4      부산대역  35.230522  129.088694
# ..   ...       ...        ...         ...
# 139  139  부산성모안과병원  35.167491  129.140791
# 140  140   센텀신세계3F  35.169063  129.129066
# 141  141    해운대중동역  35.167185  129.167886
# 142  142     센텀몰1F  35.169936  129.128342
# 143  143  그랜드조선 부산  35.160058  129.163154
#
#                                           addr           type
# 0           부산광역시 금정구 중앙대로 1989 (남산동)1522-3232  pin_generalDT
# 1           부산광역시 금정구 중앙대로 1730 (부곡동)1522-3232  pin_generalDT
# 2             부산광역시 금정구 식물원로 13 (장전동)1522-3232  pin_generalDT
# 3        부산광역시 금정구 부산대학로64번길 12 (장전동)1522-3232    pin_general
# 4    부산광역시 금정구 장전로12번길 64, 1~4층 (장전동)1522-3232    pin_general
# ..                                         ...            ...
# 139          부산광역시 해운대구 해운대로 409 (우동)1522-3232    pin_general
# 140          부산광역시 해운대구 센텀남대로 35 (우동)1522-3232    pin_general
# 141           부산광역시 해운대구 좌동순환로 6 (중동)1522-3232    pin_general
# 142           부산광역시 해운대구 센텀4로 15 (우동)1522-3232    pin_general
# 143        부산광역시 해운대구 해운대해변로 292 (중동)1522-3232    pin_general
#
# [144 rows x 6 columns]

# %%
# 방법1
gu = []
addr_list = star_data['addr']
for n in addr_list:
    gu.append(n.split(" ")[1])
star_data['구'] = gu
star_data
# Out:
#      no.      name        lat         lon  \
# 0      0   금정남산동DT  35.262179  129.091325
# 1      1    금정구청DT  35.238814  129.092986
# 2      2    온천장역DT  35.224006  129.086560
# 3      3     부산대정문  35.232122  129.084496
# 4      4      부산대역  35.230522  129.088694
# ..   ...       ...        ...         ...
# 139  139  부산성모안과병원  35.167491  129.140791
# 140  140   센텀신세계3F  35.169063  129.129066
# 141  141    해운대중동역  35.167185  129.167886
# 142  142     센텀몰1F  35.169936  129.128342
# 143  143  그랜드조선 부산  35.160058  129.163154
#
#                                           addr           type     구
# 0           부산광역시 금정구 중앙대로 1989 (남산동)1522-3232  pin_generalDT   금정구
# 1           부산광역시 금정구 중앙대로 1730 (부곡동)1522-3232  pin_generalDT   금정구
# 2             부산광역시 금정구 식물원로 13 (장전동)1522-3232  pin_generalDT   금정구
# 3        부산광역시 금정구 부산대학로64번길 12 (장전동)1522-3232    pin_general   금정구
# 4    부산광역시 금정구 장전로12번길 64, 1~4층 (장전동)1522-3232    pin_general   금정구
# ..                                         ...            ...   ...
# 139          부산광역시 해운대구 해운대로 409 (우동)1522-3232    pin_general  해운대구
# 140          부산광역시 해운대구 센텀남대로 35 (우동)1522-3232    pin_general  해운대구
# 141           부산광역시 해운대구 좌동순환로 6 (중동)1522-3232    pin_general  해운대구
# 142           부산광역시 해운대구 센텀4로 15 (우동)1522-3232    pin_general  해운대구
# 143        부산광역시 해운대구 해운대해변로 292 (중동)1522-3232    pin_general  해운대구
#
# [144 rows x 7 columns]

# %%
# 방법2
star_data['구군'] = [ a.split(" ")[1] for a in star_data['addr']]
star_data
# Out:
#      no.      name        lat         lon  \
# 0      0   금정남산동DT  35.262179  129.091325
# 1      1    금정구청DT  35.238814  129.092986
# 2      2    온천장역DT  35.224006  129.086560
# 3      3     부산대정문  35.232122  129.084496
# 4      4      부산대역  35.230522  129.088694
# ..   ...       ...        ...         ...
# 139  139  부산성모안과병원  35.167491  129.140791
# 140  140   센텀신세계3F  35.169063  129.129066
# 141  141    해운대중동역  35.167185  129.167886
# 142  142     센텀몰1F  35.169936  129.128342
# 143  143  그랜드조선 부산  35.160058  129.163154
#
#                                           addr           type     구    구군
# 0           부산광역시 금정구 중앙대로 1989 (남산동)1522-3232  pin_generalDT   금정구   금정구
# 1           부산광역시 금정구 중앙대로 1730 (부곡동)1522-3232  pin_generalDT   금정구   금정구
# 2             부산광역시 금정구 식물원로 13 (장전동)1522-3232  pin_generalDT   금정구   금정구
# 3        부산광역시 금정구 부산대학로64번길 12 (장전동)1522-3232    pin_general   금정구   금정구
# 4    부산광역시 금정구 장전로12번길 64, 1~4층 (장전동)1522-3232    pin_general   금정구   금정구
# ..                                         ...            ...   ...   ...
# 139          부산광역시 해운대구 해운대로 409 (우동)1522-3232    pin_general  해운대구  해운대구
# 140          부산광역시 해운대구 센텀남대로 35 (우동)1522-3232    pin_general  해운대구  해운대구
# 141           부산광역시 해운대구 좌동순환로 6 (중동)1522-3232    pin_general  해운대구  해운대구
# 142           부산광역시 해운대구 센텀4로 15 (우동)1522-3232    pin_general  해운대구  해운대구
# 143        부산광역시 해운대구 해운대해변로 292 (중동)1522-3232    pin_general  해운대구  해운대구
#
# [144 rows x 8 columns]

# %%
# 리눅스용 폰트 경로 설정
fontlist = fm.findSystemFonts(fontpaths=None, fontext='ttf')
fontlist
plt.rc('font', family="NanumBarunGothic")
plt.text(0.2,0.4,'한글',size=100)
# Out:
# Text(0.2, 0.4, '한글')

# %%
star_sum = star_data.groupby('구군')['구군'].count().reset_index(name="스벅수")
star_sum.plot(kind='bar', x='구군', y="스벅수")
plt.xticks(rotation=45)
plt.show()

# %%
star_sum
# Out:
#       구군  스벅수
# 0    강서구    6
# 1    금정구    8
# 2    기장군    8
# 3     남구    9
# 4     동구    4
# 5    동래구   10
# 6   부산진구   18
# 7     북구    5
# 8    사상구    8
# 9    사하구    6
# 10    서구    4
# 11   수영구   10
# 12   연제구    9
# 13   영도구    2
# 14    중구    6
# 15  해운대구   31

# %%
total =pd.merge(ingu_data, star_sum, on='구군', how = 'left')
total = total.rename(columns={"인구수(명)":"인구수"})
total
# Out:
#       구군     인구수  스벅수
# 0   해운대구  385618   31
# 1   부산진구  362505   18
# 2    사하구  302947    6
# 3     북구  275773    5
# 4    동래구  272178   10
# 5     남구  260899    9
# 6    금정구  220286    8
# 7    사상구  208794    8
# 8    연제구  206853    9
# 9    기장군  181475    8
# 10   수영구  176486   10
# 11   강서구  148540    6
# 12   영도구  109151    2
# 13    서구  106708    4
# 14    동구   90190    4
# 15    중구   41153    6

# %% [markdown]
# 부산 산업대분류, 읍·면·동별 사업체수, 종사자수 <br>
# https://kosis.kr/statHtml/statHtml.do?orgId=101&tblId=INH_1K52C01_21&conn_path=I2

# %%
biz_path = "./부산광역시구분별사업체수종사자수_2020.csv"
biz_data = pd.read_csv(biz_path, encoding="EUC-KR")
biz_data.columns = ['year','구군','type1','사업체수','종사자수']
biz = biz_data[['구군','사업체수','종사자수']]
biz
# Out:
#       구군   사업체수    종사자수
# 0     중구  17407   69849
# 1     서구  11146   46204
# 2     동구  17620   78014
# 3    영도구  11843   47016
# 4   부산진구  44530  174656
# 5    동래구  28059   96526
# 6     남구  23686   89505
# 7     북구  20780   65424
# 8   해운대구  40668  157466
# 9    사하구  29208  112556
# 10   금정구  26080   96451
# 11   강서구  31277  151971
# 12   연제구  24131   97402
# 13   수영구  20369   66064
# 14   사상구  35210  120962
# 15   기장군  18994   85019

# %%
total_m1 = pd.merge(total, biz, on='구군', how='left')
total_m1
# Out:
#       구군     인구수  스벅수   사업체수    종사자수
# 0   해운대구  385618   31  40668  157466
# 1   부산진구  362505   18  44530  174656
# 2    사하구  302947    6  29208  112556
# 3     북구  275773    5  20780   65424
# 4    동래구  272178   10  28059   96526
# 5     남구  260899    9  23686   89505
# 6    금정구  220286    8  26080   96451
# 7    사상구  208794    8  35210  120962
# 8    연제구  206853    9  24131   97402
# 9    기장군  181475    8  18994   85019
# 10   수영구  176486   10  20369   66064
# 11   강서구  148540    6  31277  151971
# 12   영도구  109151    2  11843   47016
# 13    서구  106708    4  11146   46204
# 14    동구   90190    4  17620   78014
# 15    중구   41153    6  17407   69849

# %%
# GPS정보로 지도에 표시하기
gps_path ="./gps_test.csv"
gps = pd.read_csv(gps_path,encoding="utf-8")
gps
# Out:
#             주소   Latitude   Longitude
# 0   부산광역시 해운대구  35.171946  129.174104
# 1   부산광역시 부산진구  35.165249  129.043031
# 2    부산광역시 사하구  35.089940  128.974488
# 3     부산광역시 북구  35.201183  128.998162
# 4    부산광역시 동래구  35.201753  129.083798
# 5     부산광역시 남구  35.125433  129.094277
# 6    부산광역시 금정구  35.258892  129.091536
# 7    부산광역시 사상구  35.158027  128.986590
# 8    부산광역시 연제구  35.186144  129.081633
# 9    부산광역시 기장군  35.297975  129.200920
# 10   부산광역시 수영구  35.161094  129.120104
# 11   부산광역시 강서구  35.154754  128.902756
# 12   부산광역시 영도구  35.078747  129.064765
# 13    부산광역시 서구  35.103094  129.014898
# 14    부산광역시 동구  35.127839  129.045402
# 15    부산광역시 중구  35.105470  129.031545

# %%
# !pip install folium

# %%
import folium
coordinates = gps[['Latitude','Longitude']].to_numpy()
place = gps['주소'].to_numpy()

# 중심좌표 설정(기본위치)
center_lat , center_lon = 35.17574571 , 129.0817409

# 지도생성
m = folium.Map(location=[center_lat , center_lon], zoom_start=12 )


for i, (lat, lon) in enumerate(coordinates):
    folium.CircleMarker(
        location=[lat , lon],
        radius = 30,
        color= 'orange',
        weight=1,  # 테두리 굵기 (기본값: 2)
        opacity=0.5,  # 테두리 투명도 (0.0 ~ 1.0)
        fill = True,
        fill_color = 'yellow',
        fill_opacity = 0.6,
        tooltip = place[i]
    ).add_to(m) # 지도 생성 후 원을 그리고 지도에 붙임

    folium.Marker(
        location = [lat + 0.001, lon],
        icon = folium.DivIcon(f'<div style="font-size: 9px; color: black; background-color: white; width:50px; white-space: nowrap; overflow: hidden; text-overflow: ellipsis; opactiy:0.7; border-radius:5px">{place[i]}</div>')
    ).add_to(m)
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8bb1d68492b389ce4835c3f34e20ba68 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8bb1d68492b389ce4835c3f34e20ba68&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8bb1d68492b389ce4835c3f34e20ba68 = L.map(
#                 &quot;map_8bb1d68492b389ce4835c3f34e20ba68&quot;,
#                 {
#                     center: [35.17574571, 129.0817409],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a72d36a4f250fc3b6b22f4e6480c0a88 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a72d36a4f250fc3b6b22f4e6480c0a88.addTo(map_8bb1d68492b389ce4835c3f34e20ba68);
#
#
#             var circle_marker_e842f1e52cc509b36d621fd7d0c2c745 = L.circleMarker(
#                 [35.1719465, 129.1741038],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.5, &quot;radius&quot;: 30, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_8bb1d68492b389ce4835c3f34e20ba68);
#
#
#             circle_marker_e842f1e52cc509b36d621fd7d0c2c745.bindTooltip(
#                 `&lt;div&gt;
#                      부산광역시 해운대구
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_2fce1f068857149316160bad23e3613f = L.marker(
#                 [35.172946499999995, 129.1741038],
#                 {
# }
#             ).addTo(map_8bb1d68492b389ce4835c3f34e20ba68);
#
#
#             var div_icon_2d5ad5b8ccf16558793af202ef39e0c8 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 9px; color: black; background-color: white; width:50px; white-space: nowrap; overflow: hidden; text-overflow: ellipsis; opactiy:0.7; border-radius:5px\&quot;\u003e\ubd80\uc0b0\uad11\uc5ed\uc2dc \ud574\uc6b4\ub300\uad6c\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_2fce1f068857149316160bad23e3613f.setIcon(div_icon_2d5ad5b8ccf16558793af202ef39e0c8);
#
#
#                 marker_2fce1f068857149316160bad23e3613f.setIcon(div_icon_2d5ad5b8ccf16558793af202ef39e0c8);
#
#
#             var circle_marker_b70a19610e74094cf5b1673f2de68b1d = L.circleMarker(
#                 [35.1652494, 129.0430314],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.5, &quot;radius&quot;: 30, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_8bb1d68492b389ce4835c3f34e20ba68);
#
#
#             circle_marker_b70a19610e74094cf5b1673f2de68b1d.bindTooltip(
#                 `&lt;div&gt;
#                      부산광역시 부산진구
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_0a0082fbeb79981fc55e4e38da0e5345 = L.marker(
#                 [35.1662494, 129.0430314],
#                 {
# }
#             ).addTo(map_8bb1d68492b389ce4835c3f34e20ba68);
#
#
#             var div_icon_689bc4f97af27525f98daa422c6f6cbc = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 9px; color: black; background-color: white; width:50px; white-space: nowrap; overflow: hidden; text-overflow: ellipsis; opactiy:0.7; border-radius:5px\&quot;\u003e\ubd80\uc0b0\uad11\uc5ed\uc2dc \ubd80\uc0b0\uc9c4\uad6c\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_0a0082fbeb79981fc55e4e38da0e5345.setIcon(div_icon_689bc4f97af27525f98daa422c6f6cbc);
#
#
#                 marker_0a0082fbeb79981fc55e4e38da0e5345.setIcon(div_icon_689bc4f97af27525f98daa422c6f6cbc);
#
#
#             var circle_marker_757589b52476aae29a97757512d9737d = L.circleMarker(
#                 [35.0899401, 128.9744881],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.5, &quot;radi

# %%
# !pip install geopandas
# !pip install --upgrade pyproj
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: geopandas in /home/pkdata/.local/lib/python3.10/site-packages (1.0.1)
# Requirement already satisfied: numpy>=1.22 in /home/pkdata/.local/lib/python3.10/site-packages (from geopandas) (2.2.4)
# Requirement already satisfied: pyogrio>=0.7.2 in /home/pkdata/.local/lib/python3.10/site-packages (from geopandas) (0.10.0)
# Requirement already satisfied: packaging in /home/pkdata/.local/lib/python3.10/site-packages (from geopandas) (24.2)
# Requirement already satisfied: pandas>=1.4.0 in /home/pkdata/.local/lib/python3.10/site-packages (from geopandas) (2.2.3)
# Requirement already satisfied: pyproj>=3.3.0 in /home/pkdata/.local/lib/python3.10/site-packages (from geopandas) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in /home/pkdata/.local/lib/python3.10/site-packages (from geopandas) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/pkdata/.local/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/pkdata/.local/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/pkdata/.local/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2025.2)
# Requirement already satisfied: certifi in /home/pkdata/.local/lib/python3.10/site-packages (from pyogrio>=0.7.2->geopandas) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /home/pkdata/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.17.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyproj in /home/pkdata/.local/lib/python3.10/site-packages (3.7.1)
# Requirement already satisfied: certifi in /home/pkdata/.local/lib/python3.10/site-packages (from pyproj) (2025.1.31)

# %% [markdown]
# ### 주소를 가지고 위도 / 경도 값 얻어오기(GPS 정보 얻기) 2

# %%
import geopandas as gpd
import pandas as pd
gdf = gpd.read_file("./LARD_ADM_SECT_SGG_26_202502.shp",encoding='cp949')

# 현재 좌표계 확인
print(f"현재 좌표계: {gdf.crs}")

# WSG84 좌표계로 변환 (EPSG:4326)
gdf = gdf.to_crs(epsg=4326)
coordinates=[]
for idx, row in gdf.iterrows():
    latitude = row. geometry. centroid.y
    longitude = row. geometry. centroid.x
    coordinates. append([row['SGG_NM' ],latitude, longitude])
    print(f"{row['SGG_NM']}의 중심점 좌표: 위도 {latitude}, 경도 {longitude}")

geo = pd.DataFrame(coordinates)
geo. columns=[ '구군', '위도', '경도']
geo[ '구군']=geo['구군'].str.replace( '부산광역시 ','')
geo
# Out:
# 현재 좌표계: EPSG:5186
# 사하구의 중심점 좌표: 위도 35.0889194071921, 경도 128.97407315568043
# 사상구의 중심점 좌표: 위도 35.158031116682515, 경도 128.98659031360012
# 동래구의 중심점 좌표: 위도 35.206208880252035, 경도 129.0792284050886
# 금정구의 중심점 좌표: 위도 35.25890883122911, 경도 129.09153202135272
# 연제구의 중심점 좌표: 위도 35.18240414750452, 경도 129.08296158029694
# 수영구의 중심점 좌표: 위도 35.16131959123051, 경도 129.11120194341635
# 부산진구의 중심점 좌표: 위도 35.16524570644573, 경도 129.04306325438392
# 해운대구의 중심점 좌표: 위도 35.19385029958893, 경도 129.15360577298307
# 중구의 중심점 좌표: 위도 35.1056054149738, 경도 129.03238836761827
# 남구의 중심점 좌표: 위도 35.125558325964256, 경도 129.0942822375191
# 동구의 중심점 좌표: 위도 35.12852045647495, 경도 129.0447575551209
# 영도구의 중심점 좌표: 위도 35.07868888856651, 경도 129.06480616179286
# 북구의 중심점 좌표: 위도 35.229261000621804, 경도 129.02346479725313
# 기장군의 중심점 좌표: 위도 35.297996279477196, 경도 129.20094112382552
# 서구의 중심점 좌표: 위도 35.10292316043582, 경도 129.01492725751888
# 강서구의 중심점 좌표: 위도 35.13835307158759, 경도 128.89244374229375
#       구군         위도          경도
# 0    사하구  35.088919  128.974073
# 1    사상구  35.158031  128.986590
# 2    동래구  35.206209  129.079228
# 3    금정구  35.258909  129.091532
# 4    연제구  35.182404  129.082962
# 5    수영구  35.161320  129.111202
# 6   부산진구  35.165246  129.043063
# 7   해운대구  35.193850  129.153606
# 8     중구  35.105605  129.032388
# 9     남구  35.125558  129.094282
# 10    동구  35.128520  129.044758
# 11   영도구  35.078689  129.064806
# 12    북구  35.229261  129.023465
# 13   기장군  35.297996  129.200941
# 14    서구  35.102923  129.014927
# 15   강서구  35.138353  128.892444

# %% [markdown]
# ### 주소를 가지고 위도 / 경도 값 얻어오기(GPS 정보 얻기) 3

# %%
# !pip install geopy

# %%
from geopy.geocoders import Nominatim

loc = "부산광역시 남구 대연동 1673"
geolocator = Nominatim(user_agent="geoapi")
location = geolocator.geocode(loc)
print(location.latitude, location.longitude)
# Out:
# 35.1343823 129.0938404

# %%
last= pd.merge(total_m1, geo, on="구군", how="left")
last.info()
last.sample(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   구군      16 non-null     object
#  1   인구수     16 non-null     int64
#  2   스벅수     16 non-null     int64
#  3   사업체수    16 non-null     int64
#  4   종사자수    16 non-null     int64
#  5   위도      16 non-null     float64
#  6   경도      16 non-null     float64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 1.0+ KB
#      구군     인구수  스벅수   사업체수   종사자수         위도          경도
# 9   기장군  181475    8  18994  85019  35.297996  129.200941
# 14   동구   90190    4  17620  78014  35.128520  129.044758
# 8   연제구  206853    9  24131  97402  35.182404  129.082962
# 6   금정구  220286    8  26080  96451  35.258909  129.091532
# 3    북구  275773    5  20780  65424  35.229261  129.023465

# %%
import geopandas as gpd
import json

# %%
geojson = gdf.to_json()

# %%
import folium
location_mean = last[["위도","경도"]].mean()
print(location_mean)
# Out:
# 위도     35.163862
# 경도    129.055642
# dtype: float64

# %%
def style_func(feature):
    return {'opacity' :0.7, 'weight' :1.5, 'color' : 'red', 'fillOpacity' :0, 'dashArray' : '5,5'}
    # opacity 투명도를 설정
    # weight 외곽선의 두께를 설정
    # color 경계선의 색상
    # fillopacity 면적을 채우는 색상의 투명도를 설정
    # dashArray 'dashArray': '5,5'는 5px 길이의 선과 5px 길이의 간격을 반복

sb_bubble = folium.Map(location= list(location_mean), tiles= 'CartoDB Positron', zoom_start=12) # Positron, Voyager, Dark Matter
folium.GeoJson(geojson, style_function=style_func).add_to(sb_bubble)

# 지도 출력 확인
sb_bubble
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0128850de1c928bebb16453bcfa03f17 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0128850de1c928bebb16453bcfa03f17&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0128850de1c928bebb16453bcfa03f17 = L.map(
#                 &quot;map_0128850de1c928bebb16453bcfa03f17&quot;,
#                 {
#                     center: [35.163862161139214, 129.055641730609],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ff3bda199222d3c96137fbddb2f639bf = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ff3bda199222d3c96137fbddb2f639bf.addTo(map_0128850de1c928bebb16453bcfa03f17);
#
#
#         function geo_json_70631dc20f3d3c42db22cda5d63fe79e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: &quot;5,5&quot;, &quot;fillOpacity&quot;: 0, &quot;opacity&quot;: 0.7, &quot;weight&quot;: 1.5};
#             }
#         }
#
#         function geo_json_70631dc20f3d3c42db22cda5d63fe79e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_70631dc20f3d3c42db22cda5d63fe79e = L.geoJson(null, {
#                 onEachFeature: geo_json_70631dc20f3d3c42db22cda5d63fe79e_onEachFeature,
#
#                 style: geo_json_70631dc20f3d3c42db22cda5d63fe79e_styler,
#             ...{
# }
#         });
#
#         function geo_json_70631dc20f3d3c42db22cda5d63fe79e_add (data) {
#             geo_json_70631dc20f3d3c42db22cda5d63fe79e
#                 .addData(data);
#         }
#             geo_json_70631dc20f3d3c42db22cda5d63fe79e_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[128.9517495632049, 34.884813689303364], [128.95194223673803, 34.88500508922281], [128.95197703734746, 34.88499892881912], [128.9521374100326, 34.88495032756495], [128.95226758999814, 34.88488497496648], [128.95222499401606, 34.884792582651805], [128.95221529735218, 34.88447024844715], [128.95218530502805, 34.884429907834196], [128.95210562744495, 34.884427486835904], [128.95210570322877, 34.88448373399334], [128.95195288603614, 34.884484573297335], [128.9519358932127, 34.88454712328078], [128.95183925588802, 34.884624703133056], [128.95180988301595, 34.88479153958951], [128.95177429669295, 34.88479467994748], [128.9517495632049, 34.884813689303364]]], [[[128.9732655839223, 34.933230799338766], [128.97358571579161, 34.933324374213825], [128.97358828837284, 34.93338794075824], [128.9733649124324, 34.93332975878564], [128.97332564790182, 34.93343595136507], [128.97357396985106, 34.933555532736584], [128.97421243397298, 34.93363591007908], [128.97430160857826, 34.933596268907415], [128.97387564457924, 34.93343415738671], [128.97453513819895, 34.9333011249355], [128.97431994105375, 34.933200482089205], [128.97438363387838, 34.93289534903781], [128.9741451086941, 34.93277611403645], [128.9740031243982, 34.932879363232566], [128.97333682794704, 34.93274775240565], [128.97343154847147, 34.93294188841587], [128.97372126924378, 34.93307976821343], [128.97370054292915, 34.93316483658532], [128.973348319717, 34.933103443201254], [128.9732655839223, 34.933230799338766]]], [[[128.98800007311635, 34.97888630657921], [128.9882000031389, 34.979429555540186], [128.98827314123133, 34.979542849199994], [128.98857665161748, 34.97982775452691], [128.98908838658843, 34.98004421144775], [128.98925779236384, 34.98029794056361], [128.9895227310229, 34.980398038275375], [128.9897341478077, 34.980664074689976], [128.9900428034055, 34.98095148263827], [128.99000264983547, 34.98114161637076], [128.99019717868444, 34.98111430462827], [128.99030785284853, 34.980902904698496], [128.99043179243, 34.98066548296481], [128.99059329705995, 34.98066551551858], [128.99071315041238, 34.98076480437182], [128.99088886074577, 34.98075591410423], [128.9911949106077, 34.98054434988662], [128.991542332619, 34.98089260958922], [128.99174161349214, 34.98095758825729], [128.9920354845343, 34.98092968654599], [128.99245935975517, 34.98123552145029], [128.99292063434373, 34.98126466930348], [128.9931622947484, 34.981278990937355], [128.99338160290256, 34.98129082279611], [128.99348120254606, 34.98124759908398], [128.99345319871438, 34.98091053448506], [128.99332621838846, 34.98086034613857], [128.99245913045667, 34.980928087096565], [128.99208010014783, 34.980655994367176], [128.9916257139176, 34.98038456140191], [128.9919697536637, 34.98015595314579], [128.99195306400225, 34.979960559248546], [128.99159313417755, 34.97991481251177], [128.9913097513532, 34.98017664972574], [128.99116442489728, 34.98016333312257], [1

# %%
sb_mean = last['스벅수'].mean()
sb_mean
# Out:
# np.float64(9.0)

# %%
def style_func(feature):
    return {'opacity':0.7, 'weight':1.5, 'color':'red', 'fillOpacity':0, 'dashArray':'5,5'}
sb_bubble = folium.Map(location= list(location_mean), tiles= 'CartoDB Positron', zoom_start=12) # Positron, Voyager, Dark Matter
folium.GeoJson(geojson, style_function=style_func).add_to(sb_bubble)

for i in last.index:    
    lat = float(last.loc[i, '위도'])
    lon = float(last.loc[i, '경도'])
    sb = int(last.loc[i,'스벅수'])

    if sb > sb_mean:
        fillColor = 'red'
    else:
        fillColor = 'blue'

    folium.CircleMarker(
        location=[lat,lon],
        color='yellow',
        fill_color = fillColor,
        fill_opacity=0.7,
        weight=2,
        radius=(sb*2),
     ).add_to(sb_bubble)

# 지도 출력 확인
sb_bubble
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1dc043144971f8991b96fd00708ec737 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1dc043144971f8991b96fd00708ec737&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1dc043144971f8991b96fd00708ec737 = L.map(
#                 &quot;map_1dc043144971f8991b96fd00708ec737&quot;,
#                 {
#                     center: [35.163862161139214, 129.055641730609],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bee46b1183c9ac3c55785599d848be9b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bee46b1183c9ac3c55785599d848be9b.addTo(map_1dc043144971f8991b96fd00708ec737);
#
#
#         function geo_json_825258bdde563de54562fc334538b42c_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: &quot;5,5&quot;, &quot;fillOpacity&quot;: 0, &quot;opacity&quot;: 0.7, &quot;weight&quot;: 1.5};
#             }
#         }
#
#         function geo_json_825258bdde563de54562fc334538b42c_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_825258bdde563de54562fc334538b42c = L.geoJson(null, {
#                 onEachFeature: geo_json_825258bdde563de54562fc334538b42c_onEachFeature,
#
#                 style: geo_json_825258bdde563de54562fc334538b42c_styler,
#             ...{
# }
#         });
#
#         function geo_json_825258bdde563de54562fc334538b42c_add (data) {
#             geo_json_825258bdde563de54562fc334538b42c
#                 .addData(data);
#         }
#             geo_json_825258bdde563de54562fc334538b42c_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[128.9517495632049, 34.884813689303364], [128.95194223673803, 34.88500508922281], [128.95197703734746, 34.88499892881912], [128.9521374100326, 34.88495032756495], [128.95226758999814, 34.88488497496648], [128.95222499401606, 34.884792582651805], [128.95221529735218, 34.88447024844715], [128.95218530502805, 34.884429907834196], [128.95210562744495, 34.884427486835904], [128.95210570322877, 34.88448373399334], [128.95195288603614, 34.884484573297335], [128.9519358932127, 34.88454712328078], [128.95183925588802, 34.884624703133056], [128.95180988301595, 34.88479153958951], [128.95177429669295, 34.88479467994748], [128.9517495632049, 34.884813689303364]]], [[[128.9732655839223, 34.933230799338766], [128.97358571579161, 34.933324374213825], [128.97358828837284, 34.93338794075824], [128.9733649124324, 34.93332975878564], [128.97332564790182, 34.93343595136507], [128.97357396985106, 34.933555532736584], [128.97421243397298, 34.93363591007908], [128.97430160857826, 34.933596268907415], [128.97387564457924, 34.93343415738671], [128.97453513819895, 34.9333011249355], [128.97431994105375, 34.933200482089205], [128.97438363387838, 34.93289534903781], [128.9741451086941, 34.93277611403645], [128.9740031243982, 34.932879363232566], [128.97333682794704, 34.93274775240565], [128.97343154847147, 34.93294188841587], [128.97372126924378, 34.93307976821343], [128.97370054292915, 34.93316483658532], [128.973348319717, 34.933103443201254], [128.9732655839223, 34.933230799338766]]], [[[128.98800007311635, 34.97888630657921], [128.9882000031389, 34.979429555540186], [128.98827314123133, 34.979542849199994], [128.98857665161748, 34.97982775452691], [128.98908838658843, 34.98004421144775], [128.98925779236384, 34.98029794056361], [128.9895227310229, 34.980398038275375], [128.9897341478077, 34.980664074689976], [128.9900428034055, 34.98095148263827], [128.99000264983547, 34.98114161637076], [128.99019717868444, 34.98111430462827], [128.99030785284853, 34.980902904698496], [128.99043179243, 34.98066548296481], [128.99059329705995, 34.98066551551858], [128.99071315041238, 34.98076480437182], [128.99088886074577, 34.98075591410423], [128.9911949106077, 34.98054434988662], [128.991542332619, 34.98089260958922], [128.99174161349214, 34.98095758825729], [128.9920354845343, 34.98092968654599], [128.99245935975517, 34.98123552145029], [128.99292063434373, 34.98126466930348], [128.9931622947484, 34.981278990937355], [128.99338160290256, 34.98129082279611], [128.99348120254606, 34.98124759908398], [128.99345319871438, 34.98091053448506], [128.99332621838846, 34.98086034613857], [128.99245913045667, 34.980928087096565], [128.99208010014783, 34.980655994367176], [128.9916257139176, 34.98038456140191], [128.9919697536637, 34.98015595314579], [128.99195306400225, 34.979960559248546], [128.99159313417755, 34.97991481251177], [128.9913097513532, 34.98017664972574], [128.99116442489728, 34.98016333312257], [1

# %%
# 단계 구분도 시각화
# coordinates
import json
print(type(geojson))
geojson_data = json.loads(geojson)
print(type(geojson_data))
for n in range(len(geojson_data['features'])):
    print(geojson_data['features'][n]['properties']['SGG_NM'])
# Out:
# <class 'str'>
# <class 'dict'>
# 사하구
# 사상구
# 동래구
# 금정구
# 연제구
# 수영구
# 부산진구
# 해운대구
# 중구
# 남구
# 동구
# 영도구
# 북구
# 기장군
# 서구
# 강서구

# %%
threshold_scale = [last['스벅수'].min(), last['스벅수'].quantile(0.25), last['스벅수'].quantile(0.5), last['스벅수'].quantile(0.75), last['스벅수'].max()]
sb_bubble2 = folium.Map(location=list(location_mean), tiles='CartoDB Voyager', zoom_start=12)

# 단계구분도시각화
folium.Choropleth(
    geo_data=geojson_data,
    data = last,
    columns=['구군','스벅수'],
    fill_color='PuBuGn',
    fill_opacity = 0.7,
    line_opacity=0.5,
    key_on ='feature.properties.SGG_NM',
    threshold_scale = threshold_scale,
    legend_name = "스타벅스 수"
).add_to(sb_bubble2)

sb_bubble2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2b318d21c49ef1cb110d61c3a6eb5244 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2b318d21c49ef1cb110d61c3a6eb5244&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2b318d21c49ef1cb110d61c3a6eb5244 = L.map(
#                 &quot;map_2b318d21c49ef1cb110d61c3a6eb5244&quot;,
#                 {
#                     center: [35.163862161139214, 129.055641730609],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d3bd7d1b851885a4bc46e5286f15679b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/rastertiles/voyager/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d3bd7d1b851885a4bc46e5286f15679b.addTo(map_2b318d21c49ef1cb110d61c3a6eb5244);
#
#
#             var choropleth_95b529260fac8af7c480be0a2efd6f8d = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_a3ee74521a7abd16fab8311fb89ea18a_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;8&quot;: case &quot;15&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bdc9e1&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;1&quot;: case &quot;3&quot;: case &quot;4&quot;: case &quot;9&quot;: case &quot;13&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#67a9cf&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;10&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;14&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f6eff7&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#02818a&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_a3ee74521a7abd16fab8311fb89ea18a_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_a3ee74521a7abd16fab8311fb89ea18a = L.geoJson(null, {
#                 onEachFeature: geo_json_a3ee74521a7abd16fab8311fb89ea18a_onEachFeature,
#
#                 style: geo_json_a3ee74521a7abd16fab8311fb89ea18a_styler,
#             ...{
# }
#         });
#
#         function geo_json_a3ee74521a7abd16fab8311fb89ea18a_add (data) {
#             geo_json_a3ee74521a7abd16fab8311fb89ea18a
#                 .addData(data);
#         }
#             geo_json_a3ee74521a7abd16fab8311fb89ea18a_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[128.9517495632049, 34.884813689303364], [128.95194223673803, 34.88500508922281], [128.95197703734746, 34.88499892881912], [128.9521374100326, 34.88495032756495], [128.95226758999814, 34.88488497496648], [128.95222499401606, 34.884792582651805], [128.95221529735218, 34.88447024844715], [128.95218530502805, 34.884429907834196], [128.95210562744495, 34.884427486835904], [128.95210570322877, 34.88448373399334], [128.95195288603614, 34.884484573297335], [128.9519358932127, 34.88454712328078], [128.95183925588802, 34.884624703133056], [128.95180988301595, 34.88479153958951], [128.95177429669295, 34.88479467994748], [128.9517495632049, 34.884813689303364]]], [[[128.9732655839223, 34.933230799338766], [128.97358571579161, 34.933324374213825], [128.97358828837284, 34.93338794075824], [128.9733649124324, 34.93332975878564], [128.97332564790182, 34.93343595136507], [128.97357396985106, 34.933555532736584], [128.97421243397298, 34.93363591007908], [128.97430160857826, 34.933596268907415], [128.97387564457924, 34.93343415738671], [128.97453513819895, 34.9333011249355], [128.97431994105375, 34.933200482089205], [128.97438363387838, 34.93289534903781], [128.9741451086941, 34.93277611403645], [128.9740031243982, 34.932879363232566], [128.97333682794704, 34.93274775240565], [128.97343154847147, 34.93294188841587], [128.97372126924378, 34.93307976821343], [128.97370054292915, 34.93316483658532], [128.973348319717, 34.933103443201254], [128.9732655839223, 34.933230799338766]]], [[[128.98800007311635, 34.97888630657921], [128.9882000031389, 34.979429555540186], [128.98827314123133, 34.979542849199994], [128.98857665161748, 34.97982775452691], [128.98908838658843, 34.98004421144775], [128.98925779236384, 34.98029794056361], [128.9895227310229, 34.980398038275375], [128.9897341478077, 34.98
